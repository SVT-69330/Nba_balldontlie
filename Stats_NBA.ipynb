# %% [markdown]
# # NBA Statistique

# %% [markdown]
# ## Import Module

# %%
import requests
import pandas as pd

# %%
# API_BASE_URL = 'https://www.balldontlie.io/api/v1/teams'

url = "https://api.balldontlie.io/v1/teams/24"
# params = {"full_name": "Phoenix Suns"}
headers = {"Authorization": 'f3a37e87-5594-4cff-a697-3d3aad44a0d1'}

r = requests.get(url, headers=headers)
# r = requests.get(url, params=params, headers=headers)
data = r.json()
# print(data)
data
